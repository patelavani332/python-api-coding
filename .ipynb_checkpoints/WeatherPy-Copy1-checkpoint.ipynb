# %% [markdown]
# # WeatherPy
#
# ---
#
# ## Starter Code to Generate Random Geographic Coordinates and a List of Cities

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import json
import time
from scipy.stats import linregress

# Impor the OpenWeatherMap API key
from api_keys import weather_api_key

# Import citipy to determine the cities based on latitude and longitude
from citipy import citipy

# %% [markdown]
# ### Generate the Cities List by Using the `citipy` Library

# %%
# Empty list for holding the latitude and longitude combinations
lat_lngs = []

# Empty list for holding the cities names
cities = []

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# Create a set of random lat and lng combinations
lats = np.random.uniform(lat_range[0], lat_range[1], size=1500)
lngs = np.random.uniform(lng_range[0], lng_range[1], size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
print(f"Number of cities in the list: {len(cities)}")
# Out:
# Number of cities in the list: 608

# %% [markdown]
# ---

# %% [markdown]
# ## Requirement 1: Create Plots to Showcase the Relationship Between Weather Variables and Latitude
#
# ### Use the OpenWeatherMap API to retrieve weather data from the cities list generated in the started code

# %%
# Set the API base URL
url = f"http://api.openweathermap.org/data/2.5/weather?units=matric&appid={weather_api_key}"

# Define an empty list to fetch the weather data for each city
city_data = []

# Print to logger
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters
record_count = 1
set_count = 1

# Loop through all the cities in our list to fetch weather data
for i, city in enumerate(cities):
        
    # Group cities in sets of 50 for logging purposes
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 0

    # Create endpoint URL with each city
    city_url = f"{url}&q={city}"
    
    # Log the url, record, and set numbers
    print("Processing Record %s of Set %s | %s" % (record_count, set_count, city))

    # Add 1 to the record count
    record_count += 1

    # Run an API request for each of the cities
    try:
        # Parse the JSON and retrieve data
        city_weather = requests.get(city_url).json()

        # Parse out latitude, longitude, max temp, humidity, cloudiness, wind speed, country, and date
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_date = city_weather["dt"]

        # Append the City information into city_data list
        city_data.append({"City": city, 
                          "Lat": city_lat, 
                          "Lng": city_lng, 
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Date": city_date})

    # If an error is experienced, skip the city
    except:
        print("City not found. Skipping...")
        pass
              
# Indicate that Data Loading is complete 
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | shimoda
# Processing Record 2 of Set 1 | tsihombe
# City not found. Skipping...
# Processing Record 3 of Set 1 | zhashkiv
# Processing Record 4 of Set 1 | severo-kurilsk
# Processing Record 5 of Set 1 | tikapur
# Processing Record 6 of Set 1 | bengkulu
# Processing Record 7 of Set 1 | cherskiy
# Processing Record 8 of Set 1 | albany
# Processing Record 9 of Set 1 | ushuaia
# Processing Record 10 of Set 1 | amderma
# City not found. Skipping...
# Processing Record 11 of Set 1 | torbay
# Processing Record 12 of Set 1 | meulaboh
# Processing Record 13 of Set 1 | jamestown
# Processing Record 14 of Set 1 | kahului
# Processing Record 15 of Set 1 | sambava
# Processing Record 16 of Set 1 | elat
# Processing Record 17 of Set 1 | hermanus
# Processing Record 18 of Set 1 | vaini
# Processing Record 19 of Set 1 | georgetown
# Processing Record 20 of Set 1 | zhanakorgan
# Processing Record 21 of Set 1 | avarua
# Processing Record 22 of Set 1 | neiafu
# Processing Record 23 of Set 1 | necochea
# Processing Record 24 of Set 1 | makakilo city
# Processing Record 25 of Set 1 | butaritari
# Processing Record 26 of Set 1 | haines junction
# Processing Record 27 of Set 1 | busselton
# Processing Record 28 of Set 1 | ribeira grande
# Processing Record 29 of Set 1 | arraial do cabo
# Processing Record 30 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 31 of Set 1 | tuktoyaktuk
# Processing Record 32 of Set 1 | mar del plata
# Processing Record 33 of Set 1 | isla vista
# Processing Record 34 of Set 1 | riyadh
# Processing Record 35 of Set 1 | bluff
# Processing Record 36 of Set 1 | dikson
# Processing Record 37 of Set 1 | clyde river
# Processing Record 38 of Set 1 | purpe
# Processing Record 39 of Set 1 | punta arenas
# Processing Record 40 of Set 1 | hilo
# Processing Record 41 of Set 1 | grand river south east
# City not found. Skipping...
# Processing Record 42 of Set 1 | la asuncion
# Processing Record 43 of Set 1 | barentsburg
# City not found. Skipping...
# Processing Record 44 of Set 1 | ust-omchug
# Processing Record 45 of Set 1 | odweyne
# Processing Record 46 of Set 1 | pevek
# Processing Record 47 of Set 1 | tautira
# Processing Record 48 of Set 1 | sinnamary
# Processing Record 49 of Set 1 | nikolskoye
# Processing Record 50 of Set 1 | victoria
# Processing Record 0 of Set 2 | souillac
# Processing Record 1 of Set 2 | aklavik
# Processing Record 2 of Set 2 | salalah
# Processing Record 3 of Set 2 | vestmannaeyjar
# Processing Record 4 of Set 2 | kapaa
# Processing Record 5 of Set 2 | rikitea
# Processing Record 6 of Set 2 | zyryanskoye
# Processing Record 7 of Set 2 | wanning
# Processing Record 8 of Set 2 | east london
# Processing Record 9 of Set 2 | bambous virieux
# Processing Record 10 of Set 2 | caravelas
# Processing Record 11 of Set 2 | marsh harbour
# Processing Record 12 of Set 2 | airai
# Processing Record 13 of Set 2 | kastamonu
# Processing Record 14 of Set 2 | maridi
# Processing Record 15 of Set 2 | olafsvik
# Processing Record 16 of Set 2 | bredasdorp
# Processing Record 17 of Set 2 | yellowknife
# Processing Record 18 of Set 2 | luangwa
# Processing Record 19 of Set 2 | qaanaaq
# Processing Record 20 of Set 2 | lebu
# Processing Record 21 of Set 2 | tumannyy
# City not found. Skipping...
# Processing Record 22 of Set 2 | saint-philippe
# Processing Record 23 of Set 2 | ugoofaaru
# Processing Record 24 of Set 2 | jiddah
# City not found. Skipping...
# Processing Record 25 of Set 2 | suntar
# Processing Record 26 of Set 2 | zaozerne
# Processing Record 27 of Set 2 | college
# Processing Record 28 of Set 2 | cine
# Processing Record 29 of Set 2 | hobart
# Processing Record 30 of Set 2 | mata grande
# Processing Record 31 of Set 2 | port alfred
# Processing Record 32 of Set 2 | mount gambier
# Processing Record 33 of Set 2 | navirai
# Processing Record 34 of Set 2 | karasuk
# Processing Record 35 of Set 2 | mataura
# Processing Record 36 of Set 2 | issoire
# Processing Record 37 of Set 2 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 38 of Set 2 | san patricio
# Processing Record 39 of Set 2 | faanui
# Processing Record 40 of Set 2 | bandarbeyla
# Processing Record 41 of Set 2 | pochutla
# Processing Record 42 of Set 2 | cordoba
# Processing Record 43 of Set 2 | shelburne
# Processing Record 44 of Set 2 | peniche
# Processing Record 45 of Set 2 | grand-santi
# Processing Record 46 of Set 2 | ambodifototra
# City not found. Skipping...
# Processing Record 47 of Set 2 | naze
# Processing Record 48 of Set 2 | domat
# Processing Record 49 of Set 2 | codrington
# Processing Record 0 of Set 3 | finschhafen
# Processing Record 1 of Set 3 | astoria
# Processing Record 2 of Set 3 | pathardi
# Processing Record 3 of Set 3 | hobyo
# Processing Record 4 of Set 3 | tateyama
# Processing Record 5 of Set 3 | laguna
# Processing Record 6 of Set 3 | urdzhar
# City not found. Skipping...
# Processing Record 7 of Set 3 | erenhot
# Processing Record 8 of Set 3 | lasa
# Processing Record 9 of Set 3 | vostok
# Processing Record 10 of Set 3 | quelimane
# Processing Record 11 of Set 3 | auch
# Processing Record 12 of Set 3 | south venice
# Processing Record 13 of Set 3 | nhulunbuy
# Processing Record 14 of Set 3 | umzimvubu
# City not found. Skipping...
# Processing Record 15 of Set 3 | kloulklubed
# Processing Record 16 of Set 3 | grafton
# Processing Record 17 of Set 3 | nizhneyansk
# City not found. Skipping...
# Processing Record 18 of Set 3 | yeppoon
# Processing Record 19 of Set 3 | cabo san lucas
# Processing Record 20 of Set 3 | asfi
# Processing Record 21 of Set 3 | castro
# Processing Record 22 of Set 3 | flinders
# Processing Record 23 of Set 3 | hasaki
# Processing Record 24 of Set 3 | ostrovnoy
# Processing Record 25 of Set 3 | cape town
# Processing Record 26 of Set 3 | barrow
# Processing Record 27 of Set 3 | hithadhoo
# Processing Record 28 of Set 3 | shunyi
# Processing Record 29 of Set 3 | erdenet
# Processing Record 30 of Set 3 | dubai
# Processing Record 31 of Set 3 | daitari
# Processing Record 32 of Set 3 | trincomalee
# Processing Record 33 of Set 3 | la romana
# Processing Record 34 of Set 3 | carnarvon
# Processing Record 35 of Set 3 | thompson
# Processing Record 36 of Set 3 | fortuna
# Processing Record 37 of Set 3 | san juan del sur
# Processing Record 38 of Set 3 | steinbach
# Processing Record 39 of Set 3 | saskylakh
# Processing Record 40 of Set 3 | noumea
# Processing Record 41 of Set 3 | new norfolk
# Processing Record 42 of Set 3 | mae hong son
# Processing Record 43 of Set 3 | lipin bor
# Processing Record 44 of Set 3 | gat
# Processing Record 45 of Set 3 | provideniya
# Processing Record 46 of Set 3 | oistins
# Processing Record 47 of Set 3 | mankovo-kalitvenskoye
# City not found. Skipping...
# Processing Record 48 of Set 3 | kodiak
# Processing Record 49 of Set 3 | kaitangata
# Processing Record 0 of Set 4 | bubaque
# Processing Record 1 of Set 4 | maroantsetra
# Processing Record 2 of Set 4 | eston
# Processing Record 3 of Set 4 | gizo
# Processing Record 4 of Set 4 | nishihara
# Processing Record 5 of Set 4 | cockburn town
# Processing Record 6 of Set 4 | wladyslawowo
# Processing Record 7 of Set 4 | nacala
# Processing Record 8 of Set 4 | saint-augustin
# Processing Record 9 of Set 4 | port-gentil
# Processing Record 10 of Set 4 | kavieng
# Processing Record 11 of Set 4 | salina
# Processing Record 12 of Set 4 | inhambane
# Processing Record 13 of Set 4 | saint-francois
# Processing Record 14 of Set 4 | san jose
# Processing Record 15 of Set 4 | biltine
# Processing Record 16 of Set 4 | rio grande
# Processing Record 17 of Set 4 | sept-iles
# Processing Record 18 of Set 4 | saldanha
# Processing Record 19 of Set 4 | the valley
# Processing Record 20 of Set 4 | geraldton
# Processing Record 21 of Set 4 | chokurdakh
# Processing Record 22 of Set 4 | acari
# Processing Record 23 of Set 4 | bethel
# Processing Record 24 of Set 4 | atuona
# Processing Record 25 of Set 4 | teguldet
# Processing Record 26 of Set 4 | grand centre
# City not found. Skipping...
# Processing Record 27 of Set 4 | jacareacanga
# Processing Record 28 of Set 4 | ranong
# Processing Record 29 of Set 4 | jalu
# Processing Record 30 of Set 4 | nioro
# Processing Record 31 of Set 4 | bolungarvik
# City not found. Skipping...
# Processing Record 32 of Set 4 | komsomolskiy
# Processing Record 33 of Set 4 | logrono
# Processing Record 34 of Set 4 | podgornoye
# Processing Record 35 of Set 4 | okhotsk
# Processing Record 36 of Set 4 | puerto ayora
# Processing Record 37 of Set 4 | bourail
# Processing Record 38 of Set 4 | ca mau
# Processing Record 39 of Set 4 | dallas
# Processing Record 40 of Set 4 | camana
# Processing Record 41 of Set 4 | karaul
# City not found. Skipping...
# Processing Record 42 of Set 4 | leningradskiy
# Processing Record 43 of Set 4 | vaitupu
# City not found. Skipping...
# Processing Record 44 of Set 4 | luanda
# Processing Record 45 of Set 4 | ushtobe
# Processing Record 46 of Set 4 | majene
# Processing Record 47 of Set 4 | upernavik
# Processing Record 48 of Set 4 | keflavik
# Processing Record 49 of Set 4 | lahat
# Processing Record 0 of Set 5 | taoudenni
# Processing Record 1 of Set 5 | tasiilaq
# Processing Record 2 of Set 5 | tunceli
# Processing Record 3 of Set 5 | banda aceh
# Processing Record 4 of Set 5 | yumen
# Processing Record 5 of Set 5 | ponta delgada
# Processing Record 6 of Set 5 | esperance
# Processing Record 7 of Set 5 | fare
# Processing Record 8 of Set 5 | doha
# Processing Record 9 of Set 5 | benguela
# Processing Record 10 of Set 5 | adrar
# Processing Record 11 of Set 5 | port elizabeth
# Processing Record 12 of Set 5 | glendive
# Processing Record 13 of Set 5 | port hardy
# Processing Record 14 of Set 5 | talnakh
# Processing Record 15 of Set 5 | mys shmidta
# City not found. Skipping...
# Processing Record 16 of Set 5 | takoradi
# Processing Record 17 of Set 5 | praia
# Processing Record 18 of Set 5 | sao gabriel da cachoeira
# Processing Record 19 of Set 5 | coquimbo
# Processing Record 20 of Set 5 | pastavy
# Processing Record 21 of Set 5 | ilulissat
# Processing Record 22 of Set 5 | awbari
# Processing Record 23 of Set 5 | noyabrsk
# Processing Record 24 of Set 5 | norman wells
# Processing Record 25 of Set 5 | santa barbara
# Processing Record 26 of Set 5 | parfenyevo
# Processing Record 27 of Set 5 | lengshuijiang
# Processing Record 28 of Set 5 | oda
# Processing Record 29 of Set 5 | chongwe
# Processing Record 30 of Set 5 | dembi dolo
# Processing Record 31 of Set 5 | kieta
# Processing Record 32 of Set 5 | vila franca do campo
# Processing Record 33 of Set 5 | velika kladusa
# Processing Record 34 of Set 5 | baykit
# Processing Record 35 of Set 5 | stephenville
# Processing Record 36 of Set 5 | la rioja
# Processing Record 37 of Set 5 | longyearbyen
# Processing Record 38 of Set 5 | orcopampa
# Processing Record 39 of Set 5 | harper
# Processing Record 40 of Set 5 | baturaja
# Processing Record 41 of Set 5 | namatanai
# Processing Record 42 of Set 5 | cidreira
# Processing Record 43 of Set 5 | cairns
# Processing Record 44 of Set 5 | ishinomaki
# Processing Record 45 of Set 5 | huajuapan
# City not found. Skipping...
# Processing Record 46 of Set 5 | verkhnyaya inta
# Processing Record 47 of Set 5 | mehamn
# Processing Record 48 of Set 5 | bilma
# Processing Record 49 of Set 5 | vagur
# Processing Record 0 of Set 6 | moron
# Processing Record 1 of Set 6 | shitanjing
# Processing Record 2 of Set 6 | urumqi
# Processing Record 3 of Set 6 | narsaq
# Processing Record 4 of Set 6 | klaksvik
# Processing Record 5 of Set 6 | kendari
# Processing Record 6 of Set 6 | dahuk
# Processing Record 7 of Set 6 | padang
# Processing Record 8 of Set 6 | sibolga
# Processing Record 9 of Set 6 | sheregesh
# Processing Record 10 of Set 6 | tonj
# Processing Record 11 of Set 6 | port blair
# Processing Record 12 of Set 6 | mumford
# Processing Record 13 of Set 6 | weil der stadt
# Processing Record 14 of Set 6 | opunake
# Processing Record 15 of Set 6 | juneau
# Processing Record 16 of Set 6 | olinda
# Processing Record 17 of Set 6 | belushya guba
# City not found. Skipping...
# Processing Record 18 of Set 6 | samusu
# City not found. Skipping...
# Processing Record 19 of Set 6 | kentau
# Processing Record 20 of Set 6 | broome
# Processing Record 21 of Set 6 | kabinda
# Processing Record 22 of Set 6 | kulunda
# Processing Record 23 of Set 6 | boa vista
# Processing Record 24 of Set 6 | sohbatpur
# Processing Record 25 of Set 6 | north platte
# Processing Record 26 of Set 6 | kiama
# Processing Record 27 of Set 6 | umm kaddadah
# Processing Record 28 of Set 6 | gorontalo
# Processing Record 29 of Set 6 | kroya
# Processing Record 30 of Set 6 | pangnirtung
# Processing Record 31 of Set 6 | havre-saint-pierre
# Processing Record 32 of Set 6 | warqla
# City not found. Skipping...
# Processing Record 33 of Set 6 | saint-pierre
# Processing Record 34 of Set 6 | xining
# Processing Record 35 of Set 6 | solnechnyy
# Processing Record 36 of Set 6 | moscow
# Processing Record 37 of Set 6 | walvis bay
# Processing Record 38 of Set 6 | sisimiut
# Processing Record 39 of Set 6 | crab hill
# City not found. Skipping...
# Processing Record 40 of Set 6 | pampa
# Processing Record 41 of Set 6 | kathu
# Processing Record 42 of Set 6 | kautokeino
# Processing Record 43 of Set 6 | lobito
# Processing Record 44 of Set 6 | cagayan de tawi-tawi
# City not found. Skipping...
# Processing Record 45 of Set 6 | kenitra
# Processing Record 46 of Set 6 | yerbogachen
# Processing Record 47 of Set 6 | saint anthony
# Processing Record 48 of Set 6 | quatre cocos
# Processing Record 49 of Set 6 | saint-joseph
# Processing Record 0 of Set 7 | tereze
# Processing Record 1 of Set 7 | chernyshevskiy
# Processing Record 2 of Set 7 | rayagada
# Processing Record 3 of Set 7 | zapolyarnyy
# Processing Record 4 of Set 7 | nanortalik
# Processing Record 5 of Set 7 | savalou
# Processing Record 6 of Set 7 | alofi
# Processing Record 7 of Set 7 | tyumentsevo
# Processing Record 8 of Set 7 | marawi
# Processing Record 9 of Set 7 | divo
# Processing Record 10 of Set 7 | tiksi
# Processing Record 11 of Set 7 | abiy adi
# City not found. Skipping...
# Processing Record 12 of Set 7 | sinjah
# City not found. Skipping...
# Processing Record 13 of Set 7 | khatanga
# Processing Record 14 of Set 7 | afua
# Processing Record 15 of Set 7 | teguise
# Processing Record 16 of Set 7 | zhob
# Processing Record 17 of Set 7 | goderich
# Processing Record 18 of Set 7 | dunedin
# Processing Record 19 of Set 7 | yenagoa
# Processing Record 20 of Set 7 | taonan
# Processing Record 21 of Set 7 | lewisporte
# Processing Record 22 of Set 7 | dashitou
# Processing Record 23 of Set 7 | virpur
# Processing Record 24 of Set 7 | guerrero negro
# Processing Record 25 of Set 7 | marienburg
# Processing Record 26 of Set 7 | iqaluit
# Processing Record 27 of Set 7 | sorland
# Processing Record 28 of Set 7 | port moresby
# Processing Record 29 of Set 7 | merauke
# Processing Record 30 of Set 7 | waingapu
# Processing Record 31 of Set 7 | north bend
# Processing Record 32 of Set 7 | mrirt
# City not found. Skipping...
# Processing Record 33 of Set 7 | xingyi
# Processing Record 34 of Set 7 | colwyn bay
# Processing Record 35 of Set 7 | kruisfontein
# Processing Record 36 of Set 7 | basco
# Processing Record 37 of Set 7 | newport
# Processing Record 38 of Set 7 | velke mezirici
# Processing Record 39 of Set 7 | toliary
# City not found. Skipping...
# Processing Record 40 of Set 7 | egvekinot
# Processing Record 41 of Set 7 | kampong cham
# Processing Record 42 of Set 7 | karauzyak
# City not found. Skipping...
# Processing Record 43 of Set 7 | atasu
# Processing Record 44 of Set 7 | gresham
# Processing Record 45 of Set 7 | sentyabrskiy
# City not found. Skipping...
# Processing Record 46 of Set 7 | barcelona
# Processing Record 47 of Set 7 | los llanos de aridane
# Processing Record 48 of Set 7 | zhuhai
# Processing Record 49 of Set 7 | husavik
# Processing Record 0 of Set 8 | manggar
# Processing Record 1 of Set 8 | yulara
# Processing Record 2 of Set 8 | beloha
# Processing Record 3 of Set 8 | skibbereen
# Processing Record 4 of Set 8 | pacific grove
# Processing Record 5 of Set 8 | auki
# Processing Record 6 of Set 8 | lompoc
# Processing Record 7 of Set 8 | vrede
# Processing Record 8 of Set 8 | lata
# Processing Record 9 of Set 8 | mortka
# Processing Record 10 of Set 8 | digras
# Processing Record 11 of Set 8 | ambilobe
# Processing Record 12 of Set 8 | bolama
# Processing Record 13 of Set 8 | samalaeulu
# City not found. Skipping...
# Processing Record 14 of Set 8 | ahipara
# Processing Record 15 of Set 8 | yuli
# Processing Record 16 of Set 8 | kikwit
# Processing Record 17 of Set 8 | bardiyah
# Processing Record 18 of Set 8 | pascagoula
# Processing Record 19 of Set 8 | ponta do sol
# Processing Record 20 of Set 8 | pangody
# Processing Record 21 of Set 8 | qui nhon
# Processing Record 22 of Set 8 | brae
# Processing Record 23 of Set 8 | sharjah
# Processing Record 24 of Set 8 | governador valadares
# Processing Record 25 of Set 8 | panino
# Processing Record 26 of Set 8 | qasigiannguit
# Processing Record 27 of Set 8 | attawapiskat
# City not found. Skipping...
# Processing Record 28 of Set 8 | khani
# Processing Record 29 of Set 8 | srednekolymsk
# Processing Record 30 of Set 8 | general pico
# Processing Record 31 of Set 8 | jawhar
# Processing Record 32 of Set 8 | sarh
# Processing Record 33 of Set 8 | kushiro
# Processing Record 34 of Set 8 | moshi
# Processing Record 35 of Set 8 | sao filipe
# Processing Record 36 of Set 8 | isangel
# Processing Record 37 of Set 8 | shingu
# Processing Record 38 of Set 8 | touros
# Processing Record 39 of Set 8 | audru
# Processing Record 40 of Set 8 | antofagasta
# Processing Record 41 of Set 8 | fukue
# Processing Record 42 of Set 8 | lagoa
# Processing Record 43 of Set 8 | hamilton
# Processing Record 44 of Set 8 | redlands
# Processing Record 45 of Set 8 | bandar-e lengeh
# Processing Record 46 of Set 8 | grootfontein
# Processing Record 47 of Set 8 | tabiauea
# City not found. Skipping...
# Processing Record 48 of Set 8 | maceio
# Processing Record 49 of Set 8 | chuy
# Processing Record 0 of Set 9 | hami
# Processing Record 1 of Set 9 | wajir
# Processing Record 2 of Set 9 | tessalit
# Processing Record 3 of Set 9 | sur
# Processing Record 4 of Set 9 | marcona
# City not found. Skipping...
# Processing Record 5 of Set 9 | port macquarie
# Processing Record 6 of Set 9 | hammerfest
# Processing Record 7 of Set 9 | la ronge
# Processing Record 8 of Set 9 | plettenberg bay
# Processing Record 9 of Set 9 | mandalgovi
# Processing Record 10 of Set 9 | sobolevo
# Processing Record 11 of Set 9 | jasper
# Processing Record 12 of Set 9 | san juan
# Processing Record 13 of Set 9 | svetlyy
# Processing Record 14 of Set 9 | coruripe
# Processing Record 15 of Set 9 | saint george
# Processing Record 16 of Set 9 | longjiang
# Processing Record 17 of Set 9 | kedrovyy
# Processing Record 18 of Set 9 | half moon bay
# Processing Record 19 of Set 9 | kavaratti
# Processing Record 20 of Set 9 | dauriya
# Processing Record 21 of Set 9 | mendi
# Processing Record 22 of Set 9 | loiza
# Processing Record 23 of Set 9 | greystones
# Processing Record 24 of Set 9 | pitimbu
# Processing Record 25 of Set 9 | beringovskiy
# Processing Record 26 of Set 9 | mahebourg
# Processing Record 27 of Set 9 | ekhabi
# Processing Record 28 of Set 9 | koulikoro
# Processing Record 29 of Set 9 | jinan
# Processing Record 30 of Set 9 | belmonte
# Processing Record 31 of Set 9 | grand-lahou
# Processing Record 32 of Set 9 | puerto narino
# Processing Record 33 of Set 9 | mundo nuevo
# Processing Record 34 of Set 9 | labutta
# City not found. Skipping...
# Processing Record 35 of Set 9 | hull
# Processing Record 36 of Set 9 | berlevag
# Processing Record 37 of Set 9 | ancud
# Processing Record 38 of Set 9 | dangara
# Processing Record 39 of Set 9 | grindavik
# Processing Record 40 of Set 9 | cap malheureux
# Processing Record 41 of Set 9 | pemangkat
# Processing Record 42 of Set 9 | saleilua
# City not found. Skipping...
# Processing Record 43 of Set 9 | ercis
# Processing Record 44 of Set 9 | aflu
# City not found. Skipping...
# Processing Record 45 of Set 9 | bonavista
# Processing Record 46 of Set 9 | lavrentiya
# Processing Record 47 of Set 9 | nakusp
# Processing Record 48 of Set 9 | consett
# Processing Record 49 of Set 9 | baraki barak
# Processing Record 0 of Set 10 | barawe
# City not found. Skipping...
# Processing Record 1 of Set 10 | partenit
# Processing Record 2 of Set 10 | gerede
# Processing Record 3 of Set 10 | helena
# Processing Record 4 of Set 10 | belousovka
# Processing Record 5 of Set 10 | chittaurgarh
# Processing Record 6 of Set 10 | asau
# Processing Record 7 of Set 10 | bagdarin
# Processing Record 8 of Set 10 | soddy-daisy
# Processing Record 9 of Set 10 | muzquiz
# City not found. Skipping...
# Processing Record 10 of Set 10 | vardo
# Processing Record 11 of Set 10 | sukhumi
# Processing Record 12 of Set 10 | gobabis
# Processing Record 13 of Set 10 | mgandu
# Processing Record 14 of Set 10 | svetlogorsk
# Processing Record 15 of Set 10 | xanlar
# Processing Record 16 of Set 10 | uthal
# Processing Record 17 of Set 10 | saint-georges
# Processing Record 18 of Set 10 | minsk
# Processing Record 19 of Set 10 | katsuura
# Processing Record 20 of Set 10 | kingaroy
# Processing Record 21 of Set 10 | kasempa
# Processing Record 22 of Set 10 | nome
# Processing Record 23 of Set 10 | kirakira
# Processing Record 24 of Set 10 | celestun
# Processing Record 25 of Set 10 | atar
# Processing Record 26 of Set 10 | kazalinsk
# City not found. Skipping...
# Processing Record 27 of Set 10 | banjar
# Processing Record 28 of Set 10 | sola
# Processing Record 29 of Set 10 | luderitz
# Processing Record 30 of Set 10 | tigre
# Processing Record 31 of Set 10 | payo
# Processing Record 32 of Set 10 | cabedelo
# Processing Record 33 of Set 10 | kanye
# Processing Record 34 of Set 10 | tonstad
# Processing Record 35 of Set 10 | fairbanks
# Processing Record 36 of Set 10 | mugan
# Processing Record 37 of Set 10 | kampong chhnang
# Processing Record 38 of Set 10 | mezen
# Processing Record 39 of Set 10 | yar-sale
# Processing Record 40 of Set 10 | sogdiondon
# City not found. Skipping...
# Processing Record 41 of Set 10 | aasiaat
# Processing Record 42 of Set 10 | wahpeton
# Processing Record 43 of Set 10 | kuryk
# Processing Record 44 of Set 10 | avera
# Processing Record 45 of Set 10 | mehran
# Processing Record 46 of Set 10 | meadville
# Processing Record 47 of Set 10 | gisborne
# Processing Record 48 of Set 10 | omboue
# Processing Record 49 of Set 10 | norrtalje
# Processing Record 0 of Set 11 | svetlaya
# Processing Record 1 of Set 11 | sao miguel do iguacu
# Processing Record 2 of Set 11 | prachuap khiri khan
# Processing Record 3 of Set 11 | sheridan
# Processing Record 4 of Set 11 | maghama
# City not found. Skipping...
# Processing Record 5 of Set 11 | soubre
# Processing Record 6 of Set 11 | najran
# Processing Record 7 of Set 11 | somerton
# Processing Record 8 of Set 11 | silver city
# Processing Record 9 of Set 11 | andarab
# City not found. Skipping...
# Processing Record 10 of Set 11 | mikhaylovka
# Processing Record 11 of Set 11 | alibag
# Processing Record 12 of Set 11 | vysokogornyy
# Processing Record 13 of Set 11 | tuatapere
# Processing Record 14 of Set 11 | mananjary
# Processing Record 15 of Set 11 | morden
# Processing Record 16 of Set 11 | ketchikan
# Processing Record 17 of Set 11 | lalomanu
# City not found. Skipping...
# Processing Record 18 of Set 11 | kasamwa
# Processing Record 19 of Set 11 | lorengau
# Processing Record 20 of Set 11 | luau
# Processing Record 21 of Set 11 | inyonga
# Processing Record 22 of Set 11 | tarudant
# City not found. Skipping...
# Processing Record 23 of Set 11 | faya
# Processing Record 24 of Set 11 | burica
# City not found. Skipping...
# Processing Record 25 of Set 11 | port pirie
# Processing Record 26 of Set 11 | balkanabat
# Processing Record 27 of Set 11 | bathsheba
# Processing Record 28 of Set 11 | thinadhoo
# Processing Record 29 of Set 11 | zhangzhou
# Processing Record 30 of Set 11 | port augusta
# Processing Record 31 of Set 11 | haibowan
# City not found. Skipping...
# Processing Record 32 of Set 11 | san luis
# Processing Record 33 of Set 11 | morondava
# Processing Record 34 of Set 11 | bilibino
# Processing Record 35 of Set 11 | samarai
# Processing Record 36 of Set 11 | ambulu
# Processing Record 37 of Set 11 | eskil
# Processing Record 38 of Set 11 | la tuque
# Processing Record 39 of Set 11 | tsuruoka
# Processing Record 40 of Set 11 | yomitan
# City not found. Skipping...
# Processing Record 41 of Set 11 | argostolion
# Processing Record 42 of Set 11 | nagothana
# Processing Record 43 of Set 11 | aykhal
# Processing Record 44 of Set 11 | nyurba
# Processing Record 45 of Set 11 | jakar
# Processing Record 46 of Set 11 | akureyri
# Processing Record 47 of Set 11 | bayanday
# Processing Record 48 of Set 11 | louisbourg
# City not found. Skipping...
# Processing Record 49 of Set 11 | callaway
# Processing Record 0 of Set 12 | saleaula
# City not found. Skipping...
# Processing Record 1 of Set 12 | rock springs
# Processing Record 2 of Set 12 | palmer
# Processing Record 3 of Set 12 | matara
# Processing Record 4 of Set 12 | paamiut
# Processing Record 5 of Set 12 | mogadishu
# Processing Record 6 of Set 12 | constitucion
# Processing Record 7 of Set 12 | bud
# Processing Record 8 of Set 12 | bithur
# Processing Record 9 of Set 12 | chapais
# Processing Record 10 of Set 12 | palabuhanratu
# City not found. Skipping...
# Processing Record 11 of Set 12 | ovre ardal
# Processing Record 12 of Set 12 | west wendover
# Processing Record 13 of Set 12 | zyryanka
# Processing Record 14 of Set 12 | shubarshi
# Processing Record 15 of Set 12 | kaeo
# Processing Record 16 of Set 12 | marzuq
# Processing Record 17 of Set 12 | te anau
# Processing Record 18 of Set 12 | houma
# Processing Record 19 of Set 12 | gornopravdinsk
# Processing Record 20 of Set 12 | kristiinankaupunki
# Processing Record 21 of Set 12 | petropavlovka
# Processing Record 22 of Set 12 | marshall
# Processing Record 23 of Set 12 | ilhabela
# Processing Record 24 of Set 12 | lucea
# Processing Record 25 of Set 12 | lolua
# City not found. Skipping...
# Processing Record 26 of Set 12 | chegdomyn
# Processing Record 27 of Set 12 | mvuma
# Processing Record 28 of Set 12 | de-kastri
# Processing Record 29 of Set 12 | nouadhibou
# Processing Record 30 of Set 12 | belaya gora
# Processing Record 31 of Set 12 | salinopolis
# Processing Record 32 of Set 12 | los chiles
# Processing Record 33 of Set 12 | mosquera
# Processing Record 34 of Set 12 | dhadar
# Processing Record 35 of Set 12 | lugovoy
# Processing Record 36 of Set 12 | haapiti
# Processing Record 37 of Set 12 | evans
# Processing Record 38 of Set 12 | namibe
# Processing Record 39 of Set 12 | obzor
# Processing Record 40 of Set 12 | leh
# Processing Record 41 of Set 12 | chase
# Processing Record 42 of Set 12 | vangaindrano
# Processing Record 43 of Set 12 | santa cruz
# Processing Record 44 of Set 12 | kawana waters
# City not found. Skipping...
# Processing Record 45 of Set 12 | san quintin
# Processing Record 46 of Set 12 | sovetskaya
# Processing Record 47 of Set 12 | tara
# Processing Record 48 of Set 12 | temaraia
# City not found. Skipping...
# Processing Record 49 of Set 12 | akdepe
# Processing Record 0 of Set 13 | ngukurr
# City not found. Skipping...
# Processing Record 1 of Set 13 | san andres
# Processing Record 2 of Set 13 | zarechnyy
# Processing Record 3 of Set 13 | kalmunai
# Processing Record 4 of Set 13 | nemuro
# Processing Record 5 of Set 13 | caraquet
# Processing Record 6 of Set 13 | champerico
# Processing Record 7 of Set 13 | san alberto
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Convert the cities weather data into a Pandas DataFrame
city_data_df = pd.DataFrame(city_data)

# Show Record Count
city_data_df.count()
# Out:
# City          553
# Lat           553
# Lng           553
# Max Temp      553
# Humidity      553
# Cloudiness    553
# Wind Speed    553
# Country       553
# Date          553
# dtype: int64

# %%
# Display sample data
city_data_df.head()
# Out:
#              City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0         shimoda  34.6667  138.9500    277.65        77          77
# 1        zhashkiv  49.2454   30.1102    271.40        86         100
# 2  severo-kurilsk  50.6789  156.1250    270.42        74         100
# 3         tikapur  28.5000   81.1333    286.99        56           0
# 4        bengkulu  -3.8004  102.2655    297.76        88          88
#
#    Wind Speed Country        Date
# 0        4.59      JP  1675442252
# 1        3.52      UA  1675442253
# 2        5.04      RU  1675442253
# 3        1.08      NP  1675442254
# 4        2.75      ID  1675442254

# %%
# Export the City_Data into a csv
city_data_df.to_csv("output_data/cities.csv", index_label="City_ID")

# %%
# Read saved data
city_data_df = pd.read_csv("output_data/cities.csv", index_col="City_ID")

# Display sample data
city_data_df.head()
# Out:
#                    City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# City_ID
# 0               shimoda  34.6667  138.9500    277.65        77          77
# 1              zhashkiv  49.2454   30.1102    271.40        86         100
# 2        severo-kurilsk  50.6789  156.1250    270.42        74         100
# 3               tikapur  28.5000   81.1333    286.99        56           0
# 4              bengkulu  -3.8004  102.2655    297.76        88          88
#
#          Wind Speed Country        Date
# City_ID
# 0              4.59      JP  1675442252
# 1              3.52      UA  1675442253
# 2              5.04      RU  1675442253
# 3              1.08      NP  1675442254
# 4              2.75      ID  1675442254

# %% [markdown]
# ### Create the Scatter Plots Requested
#
# #### Latitude Vs. Temperature

# %%
# Build scatter plot for latitude vs. temperature
plt.scatter(city_data_df["Lat"],city_data_df["Max Temp"],color = "yellow", edgecolor = "black", linewidths = 1, alpha = 0.8, label = "Cities")

# Incorporate the other graph properties
date = time.strftime("%Y-%m-%d")
plt.title(f"City Max Latitude vs. Temperature ({date})")
plt.xlabel("Latitude")
plt.ylabel("Max Temperature (C)")
plt.grid()
# Save the figure
plt.savefig("output_data/Fig1.png")

# Show plot
plt.show()

# %% [markdown]
# * The above plot shows that the max temperature varies as the latitude varies. As the distance of the cities from the equater changes, the max temperature of that cities changes.

# %% [markdown]
# #### Latitude Vs. Humidity

# %%
# Build the scatter plots for latitude vs. humidity
plt.scatter(city_data_df["Lat"],city_data_df["Humidity"], edgecolor = "black", linewidths = 1, alpha = 0.8, label = "Cities")

# Incorporate the other graph properties
date = time.strftime("%Y-%m-%d")
plt.title(f"City Latitude vs. Humidity ({date})")
plt.xlabel("Latitude")
plt.ylabel("Humidity (%)")
plt.grid()

# Save the figure
plt.savefig("output_data/Fig2.png")

# Show plot
plt.show()

# %% [markdown]
# * The above plot shows the relation between humidity and the city latitude. Here there is no corelation between northern and southern latitude and humidity of the city. The graph shows that maximum humidity is in northern hemisphere.

# %% [markdown]
# #### Latitude Vs. Cloudiness

# %%
# Build the scatter plots for latitude vs. cloudiness
plt.scatter(city_data_df["Lat"],city_data_df["Cloudiness"],color = "blue", edgecolor = "black", linewidths = 1, alpha = 0.8, label = "Cities")

date = time.strftime("%Y-%m-%d")
plt.title(f"City Latitude vs. Cloudiness ({date})")
plt.xlabel("Latitude")
plt.ylabel("Cloudiness (%)")
plt.grid()
# Save the figure
plt.savefig("output_data/Fig3.png")

# Show plot
plt.show()

# %% [markdown]
# * The above graph shows relationship between cloudiness and latitude of cities. Here, there is no corelation between latitude and cloudiness.

# %% [markdown]
# #### Latitude vs. Wind Speed Plot

# %%
# Build the scatter plots for latitude vs. wind speed
plt.scatter(city_data_df["Lat"],city_data_df["Wind Speed"],color = "green", edgecolor = "black", linewidths = 1, alpha = 0.8, label = "Cities")

date = time.strftime("%Y-%m-%d")
plt.title(f"City Latitude vs. Wind Speed ({date})")
plt.xlabel("Latitude")
plt.ylabel("Wind Speed (m/s)")
plt.grid()
# Save the figure
plt.savefig("output_data/Fig4.png")

# Show plot
plt.show()

# %% [markdown]
# * The above graph shows relation between wind speed and latitude. The plot shows no corelation between wind speed and latitude of the cities.

# %% [markdown]
# ---
#
# ## Requirement 2: Compute Linear Regression for Each Relationship

# %%
# Define a function to create Linear Regression plots
def plot_linear_regression(x_value, y_value, title, text_coord):    
    
    (slope, intercept, rvalue, pvalue, stderr) = linregress(x_value, y_value)
    regress_value = x_value * slope + intercept
    line_eq = f"y = {round(slope,2)}x + {round(intercept,2)}"
    
    plt.scatter(x_value, y_value)
    plt.plot(x_value , regress_value, "r-")
    plt.annotate(line_eq, text_coord, fontsize = 15, color = "red")
    plt.xlabel("Lat")
    plt.ylabel(title)
    print(f"The r-value is {rvalue ** 2}")
    plt.show

# %%
# Create a DataFrame with the Northern Hemisphere data (Latitude >= 0)
northern_hemi_df = city_data_df[city_data_df["Lat"] >= 0]

# Display sample data
northern_hemi_df.head()
# Out:
#                    City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# City_ID
# 0               shimoda  34.6667  138.9500    277.65        77          77
# 1              zhashkiv  49.2454   30.1102    271.40        86         100
# 2        severo-kurilsk  50.6789  156.1250    270.42        74         100
# 3               tikapur  28.5000   81.1333    286.99        56           0
# 5              cherskiy  68.7500  161.3000    244.64       100         100
#
#          Wind Speed Country        Date
# City_ID
# 0              4.59      JP  1675442252
# 1              3.52      UA  1675442253
# 2              5.04      RU  1675442253
# 3              1.08      NP  1675442254
# 5              0.90      RU  1675442121

# %%
# Create a DataFrame with the Southern Hemisphere data (Latitude < 0)
southern_hemi_df = city_data_df[city_data_df["Lat"] < 0]

# Display sample data
southern_hemi_df.head()
# Out:
#              City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# City_ID
# 4        bengkulu  -3.8004  102.2655    297.76        88          88
# 7         ushuaia -54.8000  -68.3000    290.96        55          75
# 12        sambava -14.2667   50.1667    299.27        87          10
# 14       hermanus -34.4187   19.2345    298.04        59           0
# 15          vaini -21.2000 -175.2000    298.24        94          75
#
#          Wind Speed Country        Date
# City_ID
# 4              2.75      ID  1675442254
# 7              6.69      AR  1675442079
# 12             3.51      MG  1675442256
# 14             8.42      ZA  1675442257
# 15             7.20      TO  1675442257

# %% [markdown]
# ###  Temperature vs. Latitude Linear Regression Plot

# %%
# Linear regression on Northern Hemisphere
x_values = northern_hemi_df["Lat"]
y_values = northern_hemi_df["Max Temp"]
plot_linear_regression(x_values, y_values, "Max Temp", (5,240))
# Out:
# The r-value is 0.717978365061688

# %%
# Linear regression on Southern Hemisphere
x_values = southern_hemi_df["Lat"]
y_values = southern_hemi_df["Max Temp"]
plot_linear_regression(x_values, y_values, "Max Temp", (-55,305))
# Out:
# The r-value is 0.24527324658561916

# %% [markdown]
# **Discussion about the linear relationship:**
# * In northern hemisphere, there is a negative corelation between maximum temperature and latitude. The maximum temperature decreases as the location of city goes away north from the equator.
# * In southern hemisphere, there is a positive corelation between maximum temperature and latitude. The maximum temperature increases as the location of city gets near the equator from south side. Also the maximum temperature varies a lot in southern hemisphere cities compared to northern hemispere cities

# %% [markdown]
# ### Humidity vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
x_values = northern_hemi_df["Lat"]
y_values = northern_hemi_df["Humidity"]
plot_linear_regression(x_values, y_values, "Humidity", (45,10))
# Out:
# The r-value is 0.24167680145773593

# %%
# Southern Hemisphere
x_values = southern_hemi_df["Lat"]
y_values = southern_hemi_df["Humidity"]
plot_linear_regression(x_values, y_values, "Humidity", (-55,35))
# Out:
# The r-value is 0.027396743459919236

# %% [markdown]
# **Discussion about the linear relationship:**
# * In northern hemisphere, there is vrey less corelation between humidity and latitude. Higher level of humidity is observed in the cities located north side of the northern hemisphere .
# * In southern hemisphere, there is no corelation between humidity and latitude. However, higher level of humidity is observed in the cities close to equator compared to the south part of soutern hemisphere cities.

# %% [markdown]
# ### Cloudiness vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
x_values = northern_hemi_df["Lat"]
y_values = northern_hemi_df["Cloudiness"]
plot_linear_regression(x_values, y_values, "Cloudiness", (45,10))
# Out:
# The r-value is 0.10536491563224679

# %%
# Southern Hemisphere
x_values = southern_hemi_df["Lat"]
y_values = southern_hemi_df["Cloudiness"]
plot_linear_regression(x_values, y_values, "Cloudiness", (-55,25))
# Out:
# The r-value is 0.08348478339375688

# %% [markdown]
# **Discussion about the linear relationship:**
# * In northern hemisphere, there is no corelation between cloudiness and latitude. The cloudiness levels are widely spread across all the latitudes.
# * In southern hemisphere, there is no corelation between cloudiness and latitude. The cloudiness levels are widely spread across all the latitudes

# %% [markdown]
# ### Wind Speed vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
x_values = northern_hemi_df["Lat"]
y_values = northern_hemi_df["Wind Speed"]
plot_linear_regression(x_values, y_values, "Wind Speed", (5,20))
# Out:
# The r-value is 0.000572184238286577

# %%
# Southern Hemisphere
x_values = southern_hemi_df["Lat"]
y_values = southern_hemi_df["Wind Speed"]
plot_linear_regression(x_values, y_values, "Wind Speed", (-50,15))
# Out:
# The r-value is 0.08856159132132509

# %% [markdown]
# **Discussion about the linear relationship:**
# * In northern hemisphere, there is no corelation at all between wind speed and latitude. Most of the cities are having different wind speeds in the range of 0 to 10 mph.
# * In southern hemisphere, there is very less negative corelation between wind speed and latitude. There is a slight increase in the wind speed of cities located away from the equator in south.
